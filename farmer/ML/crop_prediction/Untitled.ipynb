# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('crop_prediction.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Province_Name District_Name  Season      Crop
# 0           0          Koshi       Bhojpur  Kharif      rice
# 1           1          Koshi       Bhojpur  Kharif     Maize
# 2           2          Koshi       Bhojpur  Kharif    Millet
# 3           3          Koshi       Bhojpur  Kharif  Soybeans
# 4           4          Koshi       Bhojpur  Kharif     Beans

# %%
data['Season'] = data['Season'].str.rstrip()

# %%
for i in data['Season']:
    print(len(i))
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 6
# 6
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 4
# 4
# 4
# 4
# 6
# 6
# 6
# 6

# %%
list(data)
# Out:
# ['Unnamed: 0', ' Province_Name', 'District_Name', 'Season', 'Crop']

# %%
del data['Unnamed: 0']

# %%
training_data = list(np.array(data))

# %%
testing_data = training_data[100:120]

# %%
header = ['Province_Name', 'District_Name', 'Season', 'Crop']

# %%
def unique_vals(Data,col):
    return set([row[col] for row in Data])

# %%
def class_counts(Data):
    counts= {}
    for row in Data:
        label =row[-1]
        if label not in counts:
             counts[label] = 0
        counts[label] += 1
    return counts

# %%
class_counts(training_data)
# Out:
# {'rice': 1,
#  'Maize': 108,
#  'Millet': 65,
#  'Soybeans': 43,
#  'Beans': 23,
#  'Vegetables': 17,
#  'Oil Seed': 1,
#  'Sesame': 41,
#  'Castor': 1,
#  'Sunflower': 25,
#  'Wheat': 78,
#  'Barley': 68,
#  'Mustard': 78,
#  'Lentils': 77,
#  'Peas': 43,
#  'Potatoes': 70,
#  'Cabbage and Cauliflower': 15,
#  'Spinach': 46,
#  'Millets': 1,
#  'Chillies': 15,
#  'Foodder Crops': 1,
#  'Black Gram(Urad Dal)': 1,
#  'Green Gram(Moong Dal)': 1,
#  'Cowpea': 32,
#  'Paddy Rice': 1,
#  'Millets(Finger Millet, pearl Millet)': 1,
#  'Lentils (Masoor Dal)': 1,
#  'Chickpeas (Chana Dal)': 1,
#  'Mustard Greens (Toriko Saag)': 1,
#  'Radish (Mula)': 1,
#  'Carrots (Gajar)': 1,
#  'Cucumbers (Khira)': 1,
#  'Tomatoes (Golbheda)': 1,
#  'Pumpkins (Farsi)': 1,
#  'Snake Gourd (Chichindo)': 1,
#  'Bitter Gourd (Tite Karela)': 1,
#  'Bottle Gourd (Lauka)': 1,
#  'Sponge Gourd (Ghingalo)': 1,
#  'Okra (Ladyfinger)': 1,
#  'Ginger': 13,
#  'Cardamom': 13,
#  'Citrus Fruits (Oranges, Mandarins, Lemons)': 1,
#  'Buckwheat': 14,
#  'Beans and Peas': 1,
#  'Oilseeds (Sunflower, Linseed)': 1,
#  'Medicinal and Aromatic Plants (Lemongrass, Mint, Chamomile)': 1,
#  'Bamboo': 1,
#  'Rice': 75,
#  'Oilseeds': 15,
#  'Cucumber': 45,
#  'Tomato': 43,
#  'Pumpkin': 47,
#  'Bitter Gourd': 27,
#  'Bottle Gourd': 45,
#  'Sponge Gourd': 45,
#  'Okra': 16,
#  'Citrus Fruits': 12,
#  'Citrus': 1,
#  'Sorghum': 11,
#  'Pigeon pea': 26,
#  'Black gram (Urad dal)': 27,
#  'Green gram (Moong dal)': 27,
#  'Soybean': 27,
#  'Groundnut': 12,
#  'Kidney beans (Rajma)': 2,
#  "Okra (Lady's finger)": 32,
#  'Bottle gourd': 32,
#  'Bitter gourd': 32,
#  'Snake gourd': 13,
#  'Watermelon': 18,
#  'Muskmelon': 18,
#  'Sweet potato': 1,
#  'Indian spinach (Malabar spinach)': 12,
#  'Amaranth': 28,
#  'Indian mustard (Sarson)': 1,
#  'Rice (some varieties)': 1,
#  'Sponge gourd': 31,
#  'Green chili': 29,
#  'Eggplant (Brinjal)': 29,
#  'Capsicum (Bell pepper)': 18,
#  'Cucurbits like ridge gourd and sponge gourd': 4,
#  'Yardlong bean (Snake bean)': 28,
#  'Chickpeas': 28,
#  'Onions': 28,
#  'Garlic': 28,
#  'Cabbage': 33,
#  'Cauliflower': 33,
#  'Carrots': 30,
#  'Radishes': 31,
#  'Fenugreek': 11,
#  'Coriander': 29,
#  'Fennel': 27,
#  'Turnips': 26,
#  'Lettuce': 26,
#  'Beetroot': 11,
#  'Rice (some varieties can be grown in the summer season)': 3,
#  'Ridge gourd': 8,
#  'Finger millet (Ragi)': 1,
#  'Cucumbers': 34,
#  'Beets': 14,
#  'Paddy (rice)': 1,
#  'Pulses (beans, lentils, peas)': 1,
#  'Oilseeds (mustard, rapeseed, sesame)': 1,
#  'Vegetables (tomatoes, cucumbers, eggplants, okra, spinach, cabbage, cauliflower)': 1,
#  'Beans (limited varieties)': 1,
#  'Mustard greens': 2,
#  'Tomatoes': 33,
#  'peas': 1,
#  'zucchini': 1,
#  'mint': 1,
#  'basil': 1,
#  'parsley': 1,
#  'oats': 1,
#  'ryegrass': 1,
#  'silage': 1,
#  'Buckwheat (in higher altitudes)': 5,
#  'Sugarcane': 6,
#  'Beans (Kidney beans, Lima beans, etc.)': 2,
#  'Groundnuts': 9,
#  'Onion': 6,
#  'Kidney Beans': 2}

# %%
class Question:
    def __init__(self,column,value):
        self.column =column
        self.value=value
    def match(self,example):
        val = example[self.column]
        return val == self.value
    def match2(self,example):
        if example == 'True' or example == 'true' or example == '1':
            return True
        else:
            return False
    def __repr__(self):
        return "Is %s %s %s?" %(
            header[self.column],"==",str(self.value))

# %%
Question(0,'Bagmati')
# Out:
# Is Province_Name == Bagmati?

# %%
def partition(Data,question):
    true_rows,false_rows = [],[]
    for row in Data:
        if(question.match(row)):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows,false_rows

# %%
def gini(Data):
    counts = class_counts(Data)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl]/float(len(Data))
        impurity-=prob_of_lbl**2
    return impurity

# %%
def info_gain(left,right,current_uncertainity):
    p = float(len(left))/(len(left)+len(right))
    return current_uncertainity - p*gini(left) - (1-p)*gini(right)

# %%
def find_best_split(Data):
    best_gain = 0
    best_question = None
    current_uncertainity = gini(Data)
    n_features = len(Data[0]) - 1
    for col in range(n_features):
        values = unique_vals(Data,col)
        for val in values:
            question = Question(col,val)
            true_rows,false_rows = partition(Data,question)
            if(len(true_rows) == 0 or len(false_rows) == 0 ):
                continue
            gain = info_gain(true_rows,false_rows,current_uncertainity)
            if gain>best_gain:
                best_gain ,best_question =gain,question
    return best_gain,best_question

# %%
class Leaf:
    def __init__(self,Data):
        self.predictions = class_counts(Data)

# %%
class Decision_Node:
    def __init__(self,question,true_branch,false_branch):
        self.question=question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(Data,i=0):
    gain, question = find_best_split(Data)
    
    if gain == 0 : #Contains same data
        return Leaf(Data)
    true_rows,false_rows =partition(Data,question)
    true_branch = build_tree(true_rows,i)
    false_branch = build_tree(false_rows,i)
    return Decision_Node(question,true_branch,false_branch)

# %%
my_tree = build_tree(training_data)
print(my_tree)
# Out:
# <__main__.Decision_Node object at 0x00000275819E3410>

# %%
def print_tree(node,spacing=""):
    if isinstance(node,Leaf):
        print(spacing + "Predict",node.predictions)
        return
    print(spacing+str(node.question))
    print(spacing + "--> True:")
    print_tree(node.true_branch,spacing + " ")

    print(spacing + "--> False:")
    print_tree(node.false_branch,spacing + " ")

# %%
print_tree(my_tree)
# Out:
# Is Season == Rabi?
# --> True:
#  Is Province_Name == Lumbini?
#  --> True:
#   Is District_Name == Kapilvastu?
#   --> True:
#    Predict {'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Onion': 1, 'Cabbage': 1, 'Cauliflower': 1}
#   --> False:
#    Is District_Name == Rupandehi?
#    --> True:
#     Predict {'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Onion': 1, 'Cabbage': 1, 'Cauliflower': 1}
#    --> False:
#     Is District_Name == Nawalparasi?
#     --> True:
#      Predict {'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Onion': 1, 'Cabbage': 1, 'Cauliflower': 1}
#     --> False:
#      Is District_Name == Gulmi?
#      --> True:
#       Predict {'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Onion': 1}
#      --> False:
#       Is District_Name == Arghakhanchi?
#       --> True:
#        Predict {'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Onion': 1}
#       --> False:
#        Is District_Name == Palpa?
#        --> True:
#         Predict {'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Onion': 1}
#        --> False:
#         Predict {'Mustard': 7, 'Lentils': 7, 'Peas': 7, 'Potatoes': 7}
#  --> False:
#   Is Province_Name == Koshi?
#   --> True:
#    Is District_Name == Dhankuta?
#    --> True:
#     Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils (Masoor Dal)': 1, 'Chickpeas (Chana Dal)': 1, 'Mustard Greens (Toriko Saag)': 1, 'Radish (Mula)': 1, 'Carrots (Gajar)': 1, 'Potatoes': 1, 'Cabbage and Cauliflower': 1, 'Spinach': 1}
#    --> False:
#     Is District_Name == Terhathum?
#     --> True:
#      Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1}
#     --> False:
#      Is District_Name == Morang?
#      --> True:
#       Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1}
#      --> False:
#       Is District_Name == Siraha?
#       --> True:
#        Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Cabbage and Cauliflower': 1, 'Spinach': 1}
#       --> False:
#        Is District_Name == Saptari?
#        --> True:
#         Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Cabbage and Cauliflower': 1, 'Spinach': 1}
#        --> False:
#         Is District_Name == Sunsari?
#         --> True:
#          Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Cabbage and Cauliflower': 1, 'Spinach': 1}
#         --> False:
#          Is District_Name == Bhojpur?
#          --> True:
#           Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1, 'Potatoes': 1, 'Cabbage and Cauliflower': 1, 'Spinach': 1}
#          --> False:
#           Predict {'Wheat': 10, 'Barley': 10, 'Mustard': 10, 'Lentils': 10, 'Potatoes': 10, 'Cabbage and Cauliflower': 10, 'Spinach': 10}
#   --> False:
#    Is Province_Name == Karnali?
#    --> True:
#     Is District_Name == Western Rukum?
#     --> True:
#      Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1}
#     --> False:
#      Is District_Name == Salyan?
#      --> True:
#       Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1}
#      --> False:
#       Is District_Name == Surkhet?
#       --> True:
#        Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1}
#       --> False:
#        Is District_Name == Jajarkot?
#        --> True:
#         Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1}
#        --> False:
#         Is District_Name == Dailekh?
#         --> True:
#          Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Peas': 1}
#         --> False:
#          Predict {'Wheat': 5, 'Barley': 5, 'Mustard': 5, 'Lentils': 5, 'Peas': 5, 'Beans': 5}
#    --> False:
#     Is Province_Name == Sudurpaschim?
#     --> True:
#      Predict {'Wheat': 9, 'Barley': 9, 'Mustard': 9, 'Lentils': 9}
#     --> False:
#      Is District_Name == Mustang?
#      --> True:
#       Predict {'Barley': 1}
#      --> False:
#       Is District_Name == Manang?
#       --> True:
#        Predict {'Barley': 1}
#       --> False:
#        Is District_Name == Rasuwa?
#        --> True:
#         Predict {'Potatoes': 1, 'Carrots': 1, 'Radishes': 1, 'Mustard greens': 1, 'Spinach': 1}
#        --> False:
#         Is Province_Name == Madhesh?
#         --> True:
#          Predict {'Wheat': 8, 'Barley': 8, 'Mustard': 8, 'Lentils': 8, 'Chickpeas': 8, 'Peas': 8, 'Potatoes': 8, 'Onions': 8, 'Garlic': 8, 'Cabbage': 8, 'Cauliflower': 8, 'Carrots': 8, 'Radishes': 8, 'Spinach': 8, 'Fenugreek': 8, 'Coriander': 8, 'Fennel': 8, 'Turnips': 8, 'Lettuce': 8, 'Beetroot': 8}
#         --> False:
#          Is District_Name == Bhaktapur?
#          --> True:
#           Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Potatoes': 1, 'Radishes': 1, 'Carrots': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Spinach': 1, 'Coriander': 1, 'Fennel': 1, 'Turnips': 1}
#          --> False:
#           Is District_Name == Nuwakot?
#           --> True:
#            Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1}
#           --> False:
#            Is Province_Name == Bagmati?
#            --> True:
#             Is District_Name == Sindhupalchok?
#             --> True:
#              Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Coriander': 1, 'Fennel': 1}
#             --> False:
#              Is District_Name == Ramechhap?
#              --> True:
#               Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Peas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Fenugreek': 1, 'Coriander': 1, 'Fennel': 1, 'Turnips': 1, 'Lettuce': 1, 'Beetroot': 1}
#              --> False:
#               Is District_Name == Dolakha?
#               --> True:
#                Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Peas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Fenugreek': 1, 'Coriander': 1, 'Fennel': 1, 'Turnips': 1, 'Lettuce': 1, 'Beetroot': 1}
#               --> False:
#                Is District_Name == Sindhuli?
#                --> True:
#                 Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Peas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Fenugreek': 1, 'Coriander': 1, 'Fennel': 1, 'Turnips': 1, 'Lettuce': 1, 'Beetroot': 1}
#                --> False:
#                 Is District_Name == Chitwan?
#                 --> True:
#                  Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Coriander': 1, 'Fennel': 1, 'Turnips': 1, 'Lettuce': 1, 'Beets': 1}
#                 --> False:
#                  Is District_Name == Makwanpur?
#                  --> True:
#                   Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Coriander': 1, 'Fennel': 1, 'Turnips': 1, 'Lettuce': 1, 'Beets': 1}
#                  --> False:
#                   Predict {'Wheat': 4, 'Barley': 4, 'Mustard': 4, 'Lentils': 4, 'Chickpeas': 4, 'Peas': 4, 'Potatoes': 4, 'Onions': 4, 'Garlic': 4, 'Cabbage': 4, 'Cauliflower': 4, 'Carrots': 4, 'Radishes': 4, 'Spinach': 4, 'Coriander': 4, 'Fennel': 4, 'Turnips': 4, 'Lettuce': 4, 'Beets': 4}
#            --> False:
#             Is District_Name == Tanahun?
#             --> True:
#              Predict {'Wheat': 1, 'Barley': 1, 'Mustard': 1, 'Lentils': 1, 'Chickpeas': 1, 'Potatoes': 1, 'Onions': 1, 'Garlic': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Carrots': 1, 'Radishes': 1, 'Spinach': 1, 'Coriander': 1}
#             --> False:
#              Predict {'Wheat': 8, 'Barley': 8, 'Mustard': 8, 'Lentils': 8, 'Chickpeas': 8, 'Potatoes': 8, 'Onions': 8, 'Garlic': 8, 'Cabbage': 8, 'Cauliflower': 8, 'Carrots': 8, 'Radishes': 8, 'Spinach': 8, 'Coriander': 8, 'Fennel': 8, 'Turnips': 8, 'Lettuce': 8, 'Beets': 8}
# --> False:
#  Is Season == Summer?
#  --> True:
#   Is Province_Name == Lumbini?
#   --> True:
#    Is District_Name == Kapilvastu?
#    --> True:
#     Predict {'Cucumbers': 1, 'Tomatoes': 1, 'Bitter Gourd': 1, 'Bottle Gourd': 1, 'Sponge Gourd': 1, 'Okra': 1}
#    --> False:
#     Is District_Name == Rupandehi?
#     --> True:
#      Predict {'Cucumbers': 1, 'Tomatoes': 1, 'Bitter Gourd': 1, 'Bottle Gourd': 1, 'Sponge Gourd': 1, 'Okra': 1}
#     --> False:
#      Is District_Name == Nawalparasi?
#      --> True:
#       Predict {'Cucumbers': 1, 'Tomatoes': 1, 'Bitter Gourd': 1, 'Bottle Gourd': 1, 'Sponge Gourd': 1, 'Okra': 1}
#      --> False:
#       Predict {'Cucumbers': 10, 'Tomatoes': 10, 'Bitter Gourd': 10, 'Bottle Gourd': 10, 'Sponge Gourd': 10}
#   --> False:
#    Is Province_Name == Koshi?
#    --> True:
#     Is District_Name == Bhojpur?
#     --> True:
#      Predict {'Maize': 1, 'Millets': 1, 'Vegetables': 1, 'Chillies': 1, 'Sesame': 1, 'Foodder Crops': 1}
#     --> False:
#      Is District_Name == Dhankuta?
#      --> True:
#       Predict {'Cucumbers (Khira)': 1, 'Tomatoes (Golbheda)': 1, 'Pumpkins (Farsi)': 1, 'Snake Gourd (Chichindo)': 1, 'Bitter Gourd (Tite Karela)': 1, 'Bottle Gourd (Lauka)': 1, 'Sponge Gourd (Ghingalo)': 1, 'Okra (Ladyfinger)': 1, 'Ginger': 1, 'Cardamom': 1, 'Citrus Fruits (Oranges, Mandarins, Lemons)': 1, 'Buckwheat': 1, 'Beans and Peas': 1, 'Oilseeds (Sunflower, Linseed)': 1, 'Medicinal and Aromatic Plants (Lemongrass, Mint, Chamomile)': 1, 'Bamboo': 1, 'Chillies': 1, 'Cucumber': 1, 'Tomato': 1, 'Pumpkin': 1, 'Bitter Gourd': 1, 'Bottle Gourd': 1, 'Sponge Gourd': 1, 'Okra': 1, 'Citrus Fruits': 1}
#      --> False:
#       Is District_Name == Siraha?
#       --> True:
#        Predict {'Chillies': 1, 'Cucumber': 1, 'Tomato': 1, 'Pumpkin': 1, 'Bitter Gourd': 1}
#       --> False:
#        Is District_Name == Tehrathum?
#        --> True:
#         Predict {'Chillies': 1, 'Cucumber': 1, 'Tomato': 1, 'Pumpkin': 1, 'Bitter Gourd': 1, 'Bottle Gourd': 1, 'Sponge Gourd': 1, 'Okra': 1, 'Ginger': 1, 'Cardamom': 1, 'Citrus': 1}
#        --> False:
#         Predict {'Chillies': 11, 'Cucumber': 11, 'Tomato': 11, 'Pumpkin': 11, 'Bitter Gourd': 11, 'Bottle Gourd': 11, 'Sponge Gourd': 11, 'Okra': 11, 'Ginger': 11, 'Cardamom': 11, 'Citrus Fruits': 11}
#    --> False:
#     Is Province_Name == Karnali?
#     --> True:
#      Predict {'Cucumbers': 10, 'Tomatoes': 10, 'Bottle Gourd': 10, 'Sponge Gourd': 10}
#     --> False:
#      Is Province_Name == Sudurpaschim?
#      --> True:
#       Predict {'Cucumbers': 9, 'Tomatoes': 9, 'Bottle Gourd': 9, 'Sponge Gourd': 9}
#      --> False:
#       Is District_Name == Rasuwa?
#       --> True:
#        Predict {'Tomatoes': 1, 'Cucumbers': 1, 'Beans': 1, 'peas': 1, 'zucchini': 1, 'Pumpkin': 1, 'Lettuce': 1, 'Spinach': 1, 'mint': 1, 'Coriander': 1, 'basil': 1, 'parsley': 1, 'oats': 1, 'ryegrass': 1, 'silage': 1}
#       --> False:
#        Is District_Name == Mustang?
#        --> True:
#         Predict {'Potatoes': 1}
#        --> False:
#         Is District_Name == Manang?
#         --> True:
#          Predict {'Potatoes': 1}
#         --> False:
#          Is Province_Name == Madhesh?
#          --> True:
#           Is District_Name == Saptari?
#           --> True:
#            Predict {'Rice (some varieties)': 1, 'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cucurbits like ridge gourd and sponge gourd': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1}
#           --> False:
#            Is District_Name == Siraha?
#            --> True:
#             Predict {'Rice (some varieties can be grown in the summer season)': 1, 'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cucurbits like ridge gourd and sponge gourd': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1}
#            --> False:
#             Is District_Name == Mahottari?
#             --> True:
#              Predict {'Rice (some varieties can be grown in the summer season)': 1, 'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cucurbits like ridge gourd and sponge gourd': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1}
#             --> False:
#              Is District_Name == Dhanusa?
#              --> True:
#               Predict {'Rice (some varieties can be grown in the summer season)': 1, 'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cucurbits like ridge gourd and sponge gourd': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1}
#              --> False:
#               Predict {'Maize': 4, 'Watermelon': 4, 'Muskmelon': 4, 'Cucumber': 4, 'Bottle gourd': 4, 'Bitter gourd': 4, 'Snake gourd': 4, 'Pumpkin': 4, 'Sponge gourd': 4, "Okra (Lady's finger)": 4, 'Green chili': 4, 'Eggplant (Brinjal)': 4, 'Tomato': 4, 'Capsicum (Bell pepper)': 4, 'Amaranth': 4, 'Indian spinach (Malabar spinach)': 4, 'Cowpea': 4, 'Yardlong bean (Snake bean)': 4, 'Ridge gourd': 4}
#          --> False:
#           Is Province_Name == Bagmati?
#           --> True:
#            Is District_Name == Bhaktapur?
#            --> True:
#             Predict {'Maize': 1, 'Cucumbers': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1, 'Ridge gourd': 1}
#            --> False:
#             Is District_Name == Nuwakot?
#             --> True:
#              Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1}
#             --> False:
#              Is District_Name == Chitwan?
#              --> True:
#               Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1, 'Amaranth': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cabbage': 1, 'Cauliflower': 1, 'Capsicum (Bell pepper)': 1}
#              --> False:
#               Is District_Name == Ramechhap?
#               --> True:
#                Predict {'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1, 'Ridge gourd': 1}
#               --> False:
#                Is District_Name == Dolakha?
#                --> True:
#                 Predict {'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1, 'Ridge gourd': 1}
#                --> False:
#                 Is District_Name == Sindhuli?
#                 --> True:
#                  Predict {'Maize': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Sponge gourd': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Capsicum (Bell pepper)': 1, 'Amaranth': 1, 'Indian spinach (Malabar spinach)': 1, 'Cowpea': 1, 'Yardlong bean (Snake bean)': 1, 'Ridge gourd': 1}
#                 --> False:
#                  Is District_Name == Makwanpur?
#                  --> True:
#                   Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1, 'Amaranth': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Capsicum (Bell pepper)': 1}
#                  --> False:
#                   Is District_Name == Sindhupalchok?
#                   --> True:
#                    Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1, 'Amaranth': 1}
#                   --> False:
#                    Predict {'Maize': 4, 'Cucumber': 4, 'Bottle gourd': 4, 'Bitter gourd': 4, 'Sponge gourd': 4, 'Pumpkin': 4, "Okra (Lady's finger)": 4, 'Green chili': 4, 'Eggplant (Brinjal)': 4, 'Tomato': 4, 'Capsicum (Bell pepper)': 4, 'Yardlong bean (Snake bean)': 4, 'Cowpea': 4, 'Amaranth': 4}
#           --> False:
#            Is District_Name == Tanahun?
#            --> True:
#             Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1}
#            --> False:
#             Is District_Name == Lamjung?
#             --> True:
#              Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1, 'Amaranth': 1, 'Watermelon': 1, 'Muskmelon': 1}
#             --> False:
#              Is District_Name == Gorkha?
#              --> True:
#               Predict {'Maize': 1, 'Cucumber': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Pumpkin': 1, "Okra (Lady's finger)": 1, 'Green chili': 1, 'Eggplant (Brinjal)': 1, 'Tomato': 1, 'Yardlong bean (Snake bean)': 1, 'Cowpea': 1, 'Amaranth': 1, 'Watermelon': 1, 'Muskmelon': 1}
#              --> False:
#               Predict {'Maize': 6, 'Cucumber': 6, 'Bottle gourd': 6, 'Bitter gourd': 6, 'Sponge gourd': 6, 'Pumpkin': 6, "Okra (Lady's finger)": 6, 'Green chili': 6, 'Eggplant (Brinjal)': 6, 'Tomato': 6, 'Yardlong bean (Snake bean)': 6, 'Cowpea': 6, 'Amaranth': 6}
#  --> False:
#   Is Province_Name == Lumbini?
#   --> True:
#    Is District_Name == Eastern Rukum?
#    --> True:
#     Predict {'Rice': 1, 'Maize': 1, 'Wheat': 1, 'Soybeans': 1, 'Millet': 1}
#    --> False:
#     Is District_Name == Rolpa?
#     --> True:
#      Predict {'Rice': 1, 'Maize': 1, 'Wheat': 1, 'Soybeans': 1}
#     --> False:
#      Is District_Name == Arghakhanchi?
#      --> True:
#       Predict {'Rice': 1, 'Maize': 1, 'Soybeans': 1, 'Wheat': 1}
#      --> False:
#       Is District_Name == Parasi?
#       --> True:
#        Predict {'Rice': 1, 'Maize': 1, 'Soybeans': 1, 'Wheat': 1}
#       --> False:
#        Is District_Name == Kapilvastu?
#        --> True:
#         Predict {'Rice': 1, 'Maize': 1, 'Wheat': 1, 'Soybeans': 1, 'Groundnuts': 1, 'Sugarcane': 1}
#        --> False:
#         Is District_Name == Rupandehi?
#         --> True:
#          Predict {'Rice': 1, 'Maize': 1, 'Wheat': 1, 'Soybeans': 1, 'Groundnuts': 1, 'Sugarcane': 1}
#         --> False:
#          Is District_Name == Palpa?
#          --> True:
#           Predict {'Rice': 1, 'Maize': 1, 'Wheat': 1, 'Soybeans': 1, 'Groundnuts': 1, 'Sugarcane': 1}
#          --> False:
#           Is District_Name == Nawalparasi?
#           --> True:
#            Predict {'Rice': 1, 'Maize': 1, 'Wheat': 1, 'Soybeans': 1, 'Groundnuts': 1, 'Sugarcane': 1}
#           --> False:
#            Predict {'Rice': 5, 'Maize': 5, 'Wheat': 5, 'Soybeans': 5, 'Groundnuts': 5}
#   --> False:
#    Is Province_Name == Koshi?
#    --> True:
#     Is District_Name == Dhankuta?
#     --> True:
#      Predict {'Black Gram(Urad Dal)': 1, 'Green Gram(Moong Dal)': 1, 'Cowpea': 1, 'Sesame': 1, 'Paddy Rice': 1, 'Maize': 1, 'Millets(Finger Millet, pearl Millet)': 1, 'Soybeans': 1}
#     --> False:
#      Is District_Name == Bhojpur?
#      --> True:
#       Predict {'rice': 1, 'Maize': 1, 'Millet': 1, 'Soybeans': 1, 'Beans': 1, 'Vegetables': 1, 'Oil Seed': 1, 'Sesame': 1, 'Castor': 1, 'Sunflower': 1}
#      --> False:
#       Is District_Name == Sankhuwasabha?
#       --> True:
#        Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybeans': 1, 'Beans': 1, 'Vegetables': 1, 'Oilseeds': 1, 'Buckwheat': 1}
#       --> False:
#        Is District_Name == Terhathum?
#        --> True:
#         Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybeans': 1, 'Beans': 1, 'Vegetables': 1, 'Oilseeds': 1, 'Buckwheat': 1}
#        --> False:
#         Is District_Name == Udayapur?
#         --> True:
#          Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybeans': 1, 'Beans': 1, 'Vegetables': 1, 'Oilseeds': 1}
#         --> False:
#          Predict {'Rice': 12, 'Maize': 12, 'Millet': 12, 'Soybeans': 12, 'Beans': 12, 'Vegetables': 12, 'Oilseeds': 12, 'Sesame': 12, 'Sunflower': 12}
#    --> False:
#     Is Province_Name == Sudurpaschim?
#     --> True:
#      Predict {'Rice': 9, 'Maize': 9, 'Millet': 9, 'Soybeans': 9}
#     --> False:
#      Is Province_Name == Karnali?
#      --> True:
#       Is District_Name == Western Rukum?
#       --> True:
#        Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybeans': 1, 'Kidney Beans': 1, 'Potatoes': 1}
#       --> False:
#        Is District_Name == Salyan?
#        --> True:
#         Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybeans': 1, 'Kidney Beans': 1, 'Potatoes': 1}
#        --> False:
#         Is District_Name == Surkhet?
#         --> True:
#          Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Buckwheat': 1, 'Soybeans': 1}
#         --> False:
#          Is District_Name == Dailekh?
#          --> True:
#           Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Buckwheat': 1, 'Soybeans': 1}
#          --> False:
#           Is District_Name == Jajarkot?
#           --> True:
#            Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Buckwheat': 1, 'Beans': 1, 'Potatoes': 1}
#           --> False:
#            Predict {'Rice': 5, 'Maize': 5, 'Buckwheat': 5, 'Millet': 5, 'Potatoes': 5}
#      --> False:
#       Is District_Name == Rasuwa?
#       --> True:
#        Predict {'Potatoes': 1, 'Buckwheat': 1, 'Beans (limited varieties)': 1, 'Radishes': 1, 'Mustard greens': 1}
#       --> False:
#        Is Province_Name == Gandaki?
#        --> True:
#         Is District_Name == Mustang?
#         --> True:
#          Predict {'Barley': 1}
#         --> False:
#          Is District_Name == Manang?
#          --> True:
#           Predict {'Buckwheat': 1}
#          --> False:
#           Is District_Name == Tanahun?
#           --> True:
#            Predict {'Rice': 1, 'Maize': 1, 'Millet': 1}
#           --> False:
#            Is District_Name == Lamjung?
#            --> True:
#             Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Buckwheat (in higher altitudes)': 1, 'Beans (Kidney beans, Lima beans, etc.)': 1}
#            --> False:
#             Is District_Name == Gorkha?
#             --> True:
#              Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Buckwheat (in higher altitudes)': 1, 'Beans (Kidney beans, Lima beans, etc.)': 1}
#             --> False:
#              Is District_Name == Baglung?
#              --> True:
#               Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Buckwheat (in higher altitudes)': 1}
#              --> False:
#               Is District_Name == Kaski?
#               --> True:
#                Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Buckwheat (in higher altitudes)': 1}
#               --> False:
#                Predict {'Rice': 4, 'Maize': 4, 'Millet': 4, 'Soybean': 4, 'Green gram (Moong dal)': 4, 'Black gram (Urad dal)': 4, 'Pigeon pea': 4, 'Sesame': 4}
#        --> False:
#         Is District_Name == Kathmandu?
#         --> True:
#          Predict {'Paddy (rice)': 1, 'Maize': 1, 'Millet': 1, 'Pulses (beans, lentils, peas)': 1, 'Oilseeds (mustard, rapeseed, sesame)': 1, 'Vegetables (tomatoes, cucumbers, eggplants, okra, spinach, cabbage, cauliflower)': 1}
#         --> False:
#          Is District_Name == Saptari?
#          --> True:
#           Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Sorghum': 1, 'Pigeon pea': 1, 'Black gram (Urad dal)': 1, 'Green gram (Moong dal)': 1, 'Soybean': 1, 'Sesame': 1, 'Groundnut': 1, 'Sunflower': 1, 'Cowpea': 1, 'Kidney beans (Rajma)': 1, "Okra (Lady's finger)": 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Snake gourd': 1, 'Pumpkin': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Cucumber': 1, 'Sweet potato': 1, 'Indian spinach (Malabar spinach)': 1, 'Amaranth': 1, 'Indian mustard (Sarson)': 1}
#          --> False:
#           Is District_Name == Makwanpur?
#           --> True:
#            Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Sugarcane': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Pumpkin': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Cucumber': 1, "Okra (Lady's finger)": 1, 'Cowpea': 1}
#           --> False:
#            Is District_Name == Chitwan?
#            --> True:
#             Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Sugarcane': 1, 'Watermelon': 1, 'Muskmelon': 1, 'Pumpkin': 1, 'Bottle gourd': 1, 'Bitter gourd': 1, 'Sponge gourd': 1, 'Cucumber': 1, "Okra (Lady's finger)": 1, 'Cowpea': 1, 'Sunflower': 1}
#            --> False:
#             Is District_Name == Bhaktapur?
#             --> True:
#              Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Buckwheat': 1, 'Finger millet (Ragi)': 1, 'Soybean': 1, 'Black gram (Urad dal)': 1, 'Green gram (Moong dal)': 1, 'Kidney beans (Rajma)': 1, 'Lentils': 1}
#             --> False:
#              Is Province_Name == Bagmati?
#              --> True:
#               Is District_Name == Sindhupalchok?
#               --> True:
#                Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Buckwheat (in higher altitudes)': 1}
#               --> False:
#                Is District_Name == Dhading?
#                --> True:
#                 Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1}
#                --> False:
#                 Is District_Name == Lalitpur?
#                 --> True:
#                  Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1}
#                 --> False:
#                  Is District_Name == Nuwakot?
#                  --> True:
#                   Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1}
#                  --> False:
#                   Is District_Name == Kavrepalanchok?
#                   --> True:
#                    Predict {'Rice': 1, 'Maize': 1, 'Millet': 1, 'Soybean': 1, 'Green gram (Moong dal)': 1, 'Black gram (Urad dal)': 1, 'Pigeon pea': 1, 'Sesame': 1, 'Groundnut': 1}
#                   --> False:
#                    Predict {'Rice': 3, 'Maize': 3, 'Millet': 3, 'Sorghum': 3, 'Pigeon pea': 3, 'Black gram (Urad dal)': 3, 'Green gram (Moong dal)': 3, 'Soybean': 3, 'Sesame': 3, 'Groundnut': 3, 'Sunflower': 3}
#              --> False:
#               Predict {'Rice': 7, 'Maize': 7, 'Millet': 7, 'Sorghum': 7, 'Pigeon pea': 7, 'Black gram (Urad dal)': 7, 'Green gram (Moong dal)': 7, 'Soybean': 7, 'Sesame': 7, 'Groundnut': 7, 'Sunflower': 7}

# %%
def print_leaf(counts):
    total = sum(counts.values())*1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] =str(int(counts[lbl]/total * 100)) + "%"
    return probs

# %%
def classify(row,node):
    if isinstance(node,Leaf):
        return node.predictions
    if node.question.match(row):
        return classify(row,node.true_branch)
    else:
        return classify(row,node.false_branch)

# %%
import pickle
# Dump the trained Naive Bayes classifier with Pickle
RF_pkl_filename = 'cropprediction.pkl'
# Open the file to save as pkl file
RF_Model_pkl = open(RF_pkl_filename, 'wb')
pickle.dump(my_tree, RF_Model_pkl)
# Close the pickle instances
RF_Model_pkl.close()
